# %%
import pandas as pd

# %%
raw = pd.read_csv('poker_now_log_pgl7k46MACS85n1zyaBl-yyT9.csv')

# %%
[entry for entry in raw['entry']][::-1]
# Out:
# ['The player "Dirty Diaper @ AvoHls2e56" requested a seat.',
#  'The admin approved the player "Dirty Diaper @ AvoHls2e56" participation with a stack of 15.',
#  'WARNING: the admin queued the stack change for the player "Dirty Diaper @ AvoHls2e56" adding 14.85 chips in the next hand.',
#  'The admin updated the player "Dirty Diaper @ AvoHls2e56" stack from 0.15 to 15.00.',
#  'The player "JackofHearts @ _kHfP4SW17" requested a seat.',
#  'The admin approved the player "JackofHearts @ _kHfP4SW17" participation with a stack of 15.00.',
#  'The player "Owen @ yW0aVOwsyd" requested a seat.',
#  'The admin approved the player "Owen @ yW0aVOwsyd" participation with a stack of 15.00.',
#  '-- starting hand #1 (id: me8lcjtiqib8)  (No Limit Texas Hold\'em) (dealer: "Dirty Diaper @ AvoHls2e56") --',
#  'The player "Dirty Diaper @ AvoHls2e56" joined the game with a stack of 15.00.',
#  'The player "JackofHearts @ _kHfP4SW17" joined the game with a stack of 15.00.',
# ...

# %%
{
    'players',
    'positions',
    'hand',
    'pot',
    'preflop_action',
    'flop',
    'postflop-action',
    'turn',
    'preriver_action',
    'river',
    'postriver_action',
    'winner',
    'winning_hand'
}
